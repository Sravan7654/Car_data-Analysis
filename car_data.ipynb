# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car_data = pd.read_csv('C:/Users/Admin/Desktop/car data base/final_scout_not_dummy.csv')
car_data.head(2)
# Out:
#   make_model body_type  price               vat       km  Type     Fuel  \
# 0    Audi A1    Sedans  15770    VAT deductible  56013.0  Used   Diesel
# 1    Audi A1    Sedans  14500  Price negotiable  80000.0  Used  Benzine
#
#    Gears                                Comfort_Convenience  \
# 0    7.0  Air conditioning,Armrest,Automatic climate con...
# 1    7.0  Air conditioning,Automatic climate control,Hil...
#
#                                  Entertainment_Media  ... Previous_Owners  \
# 0  Bluetooth,Hands-free equipment,On-board comput...  ...             2.0
# 1  Bluetooth,Hands-free equipment,On-board comput...  ...             1.0
#
#    hp_kW  Inspection_new  Paint_Type  Upholstery_type  Gearing_Type  \
# 0   66.0               1    Metallic            Cloth     Automatic
# 1  141.0               0    Metallic            Cloth     Automatic
#
#   Displacement_cc Weight_kg Drive_chain  cons_comb
# 0          1422.0    1220.0       front        3.8
# ...

# %%
car_data.shape
# Out:
# (15915, 23)

# %%
type(car_data)
# Out:
# pandas.core.frame.DataFrame

# %%
car_data.tail()
# Out:
#            make_model body_type  price             vat           km  \
# 15910  Renault Espace       Van  39950  VAT deductible  1647.362609
# 15911  Renault Espace       Van  39885  VAT deductible  9900.000000
# 15912  Renault Espace       Van  39875  VAT deductible    15.000000
# 15913  Renault Espace       Van  39700  VAT deductible    10.000000
# 15914  Renault Espace       Van  40999  VAT deductible  1647.362609
#
#                  Type     Fuel  Gears  \
# 15910             New   Diesel    6.0
# 15911            Used  Benzine    7.0
# 15912  Pre-registered   Diesel    6.0
# 15913  Pre-registered   Diesel    6.0
# 15914   Demonstration  Benzine    6.0
#
#                                      Comfort_Convenience  \
# 15910  Air conditioning,Automatic climate control,Cru...
# 15911  Air conditioning,Automatic climate control,Cru...
# 15912  Air conditioning,Armrest,Automatic climate con...
# 15913  Air conditioning,Automatic climate control,Cru...
# ...

# %%
car_data.columns
# Out:
# Index(['make_model', 'body_type', 'price', 'vat', 'km', 'Type', 'Fuel',
#        'Gears', 'Comfort_Convenience', 'Entertainment_Media', 'Extras',
#        'Safety_Security', 'age', 'Previous_Owners', 'hp_kW', 'Inspection_new',
#        'Paint_Type', 'Upholstery_type', 'Gearing_Type', 'Displacement_cc',
#        'Weight_kg', 'Drive_chain', 'cons_comb'],
#       dtype='object')

# %%
car_data.dtypes
# Out:
# make_model              object
# body_type               object
# price                    int64
# vat                     object
# km                     float64
# Type                    object
# Fuel                    object
# Gears                  float64
# Comfort_Convenience     object
# Entertainment_Media     object
# Extras                  object
# Safety_Security         object
# age                    float64
# Previous_Owners        float64
# hp_kW                  float64
# Inspection_new           int64
# Paint_Type              object
# Upholstery_type         object
# Gearing_Type            object
# Displacement_cc        float64
# Weight_kg              float64
# Drive_chain             object
# cons_comb              float64
# dtype: object

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15915 entries, 0 to 15914
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   make_model           15915 non-null  object
#  1   body_type            15915 non-null  object
#  2   price                15915 non-null  int64
#  3   vat                  15915 non-null  object
#  4   km                   15915 non-null  float64
#  5   Type                 15915 non-null  object
#  6   Fuel                 15915 non-null  object
#  7   Gears                15915 non-null  float64
#  8   Comfort_Convenience  15915 non-null  object
#  9   Entertainment_Media  15915 non-null  object
#  10  Extras               15915 non-null  object
#  11  Safety_Security      15915 non-null  object
#  12  age                  15915 non-null  float64
#  13  Previous_Owners      15915 non-null  float64
#  14  hp_kW                15915 non-null  float64
# ...

# %%
car_data.isnull().sum()
# Out:
# make_model             0
# body_type              0
# price                  0
# vat                    0
# km                     0
# Type                   0
# Fuel                   0
# Gears                  0
# Comfort_Convenience    0
# Entertainment_Media    0
# Extras                 0
# Safety_Security        0
# age                    0
# Previous_Owners        0
# hp_kW                  0
# Inspection_new         0
# Paint_Type             0
# Upholstery_type        0
# Gearing_Type           0
# Displacement_cc        0
# Weight_kg              0
# Drive_chain            0
# cons_comb              0
# dtype: int64

# %%
car_data['Fuel'].mode()
# Out:
# 0    Benzine
# Name: Fuel, dtype: object

# %%
print(car_data['Gears'].mean())
print(car_data['Gears'].median())
print(car_data['Gears'].mode())
# Out:
# 5.937354696826893
# 6.0
# 0    6.0
# Name: Gears, dtype: float64

# %%
print(car_data['Displacement_cc'].mean())
print(car_data['Displacement_cc'].median())
print(car_data['Displacement_cc'].mode())
# Out:
# 1428.661891297518
# 1461.0
# 0    1598.0
# Name: Displacement_cc, dtype: float64

# %%
dup_car_data = car_data[car_data.duplicated()]
dup_car_data
# Out:
#            make_model body_type  price             vat            km  \
# 81            Audi A1    Sedans  18500  VAT deductible  13406.000000
# 123           Audi A1    Sedans  18700  VAT deductible  27000.000000
# 136           Audi A1   Compact  18333  VAT deductible   4800.000000
# 287           Audi A1    Sedans  15090  VAT deductible  63668.000000
# 291           Audi A1    Sedans  15090  VAT deductible  63668.000000
# ...               ...       ...    ...             ...           ...
# 15889  Renault Espace       Van  42500  VAT deductible     10.000000
# 15897  Renault Espace       Van  41400  VAT deductible     10.000000
# 15910  Renault Espace       Van  39950  VAT deductible   1647.362609
# 15913  Renault Espace       Van  39700  VAT deductible     10.000000
# 15914  Renault Espace       Van  40999  VAT deductible   1647.362609
#
#                  Type     Fuel  Gears  \
# 81               Used   Diesel    7.0
# 123    Employee's car   Diesel    7.0
# ...

# %%
cardata = car_data.drop_duplicates()
cardata.shape
# Out:
# (14242, 23)

# %%
car_data.head()
# Out:
#   make_model body_type  price               vat       km  Type     Fuel  \
# 0    Audi A1    Sedans  15770    VAT deductible  56013.0  Used   Diesel
# 1    Audi A1    Sedans  14500  Price negotiable  80000.0  Used  Benzine
# 2    Audi A1    Sedans  14640    VAT deductible  83450.0  Used   Diesel
# 3    Audi A1    Sedans  14500    VAT deductible  73000.0  Used   Diesel
# 4    Audi A1    Sedans  16790    VAT deductible  16200.0  Used   Diesel
#
#    Gears                                Comfort_Convenience  \
# 0    7.0  Air conditioning,Armrest,Automatic climate con...
# 1    7.0  Air conditioning,Automatic climate control,Hil...
# 2    7.0  Air conditioning,Cruise control,Electrical sid...
# 3    6.0  Air suspension,Armrest,Auxiliary heating,Elect...
# 4    7.0  Air conditioning,Armrest,Automatic climate con...
#
#                                  Entertainment_Media  ... Previous_Owners  \
# 0  Bluetooth,Hands-free equipment,On-board comput...  ...             2.0
# ...

# %%
car_data['make_model'].unique()
# Out:
# array(['Audi A1', 'Audi A2', 'Audi A3', 'Opel Astra', 'Opel Corsa',
#        'Opel Insignia', 'Renault Clio', 'Renault Duster',
#        'Renault Espace'], dtype=object)

# %%
car_data['make_model'].nunique()
# Out:
# 9

# %%
car_data['make_model'].value_counts()
# Out:
# make_model
# Audi A3           3097
# Audi A1           2614
# Opel Insignia     2598
# Opel Astra        2525
# Opel Corsa        2216
# Renault Clio      1839
# Renault Espace     991
# Renault Duster      34
# Audi A2              1
# Name: count, dtype: int64

# %%
car_data['body_type'].value_counts()
# Out:
# body_type
# Sedans           8004
# Station wagon    3677
# Compact          3240
# Van               817
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: count, dtype: int64

# %%
car_data.describe()
# Out:
#               price             km         Gears           age  \
# count  15915.000000   15915.000000  15915.000000  15915.000000
# mean   18024.380584   32089.995708      5.937355      1.389695
# std     7381.679318   36977.214964      0.704772      1.121306
# min     4950.000000       0.000000      5.000000      0.000000
# 25%    12850.000000    1920.500000      5.000000      0.000000
# 50%    16900.000000   20413.000000      6.000000      1.000000
# 75%    21900.000000   46900.000000      6.000000      2.000000
# max    74600.000000  317000.000000      8.000000      3.000000
#
#        Previous_Owners         hp_kW  Inspection_new  Displacement_cc  \
# count     15915.000000  15915.000000    15915.000000     15915.000000
# mean          1.042853     88.499340        0.247063      1428.661891
# std           0.339178     26.674341        0.431317       275.804272
# min           0.000000     40.000000        0.000000       890.000000
# ...

# %%
max_price = car_data['price'].max()
max_price
# Out:
# np.int64(74600)

# %%
car_data[car_data['price'] == max_price]
# Out:
#      make_model body_type  price             vat       km  Type     Fuel  \
# 3648    Audi A3    Sedans  74600  VAT deductible  13000.0  Used  Benzine
#
#       Gears                                Comfort_Convenience  \
# 3648    7.0  Air conditioning,Armrest,Automatic climate con...
#
#                     Entertainment_Media  ... Previous_Owners  hp_kW  \
# 3648  CD player,On-board computer,Radio  ...             1.0  294.0
#
#       Inspection_new  Paint_Type    Upholstery_type    Gearing_Type  \
# 3648               0    Metallic  Part/Full Leather  Semi-automatic
#
#      Displacement_cc Weight_kg Drive_chain  cons_comb
# 3648          2480.0    1490.0         4WD        8.3
#
# [1 rows x 23 columns]

# %%
car_data.make_model
# Out:
# 0               Audi A1
# 1               Audi A1
# 2               Audi A1
# 3               Audi A1
# 4               Audi A1
#               ...
# 15910    Renault Espace
# 15911    Renault Espace
# 15912    Renault Espace
# 15913    Renault Espace
# 15914    Renault Espace
# Name: make_model, Length: 15915, dtype: object

# %%
car_data['make_model'].value_counts(ascending =True)
# Out:
# make_model
# Audi A2              1
# Renault Duster      34
# Renault Espace     991
# Renault Clio      1839
# Opel Corsa        2216
# Opel Astra        2525
# Opel Insignia     2598
# Audi A1           2614
# Audi A3           3097
# Name: count, dtype: int64

# %%
car_data['make_model'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='make_model'>

# %%
car_data['body_type'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='body_type'>

# %%
car_data['Fuel'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Fuel'>

# %%
car_data['price'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_data['age'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_data['body_type'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='body_type'>

# %%
car_data[(car_data['price'] >10000) & (car_data['price'] <20000)]
# Out:
#            make_model    body_type  price               vat        km  Type  \
# 0             Audi A1       Sedans  15770    VAT deductible   56013.0  Used
# 1             Audi A1       Sedans  14500  Price negotiable   80000.0  Used
# 2             Audi A1       Sedans  14640    VAT deductible   83450.0  Used
# 3             Audi A1       Sedans  14500    VAT deductible   73000.0  Used
# 4             Audi A1       Sedans  16790    VAT deductible   16200.0  Used
# ...               ...          ...    ...               ...       ...   ...
# 15415  Renault Espace  Transporter  18850    VAT deductible  110000.0  Used
# 15416  Renault Espace  Transporter  17500    VAT deductible  120000.0  Used
# 15417  Renault Espace  Transporter  17500    VAT deductible   93000.0  Used
# 15418  Renault Espace  Transporter  19000  Price negotiable   85000.0  Used
# 15419  Renault Espace  Transporter  17300    VAT deductible   79000.0  Used
#
# ...

# %%
car_data[(car_data['km'] >10000)]
# Out:
#            make_model      body_type  price               vat       km  \
# 0             Audi A1         Sedans  15770    VAT deductible  56013.0
# 1             Audi A1         Sedans  14500  Price negotiable  80000.0
# 2             Audi A1         Sedans  14640    VAT deductible  83450.0
# 3             Audi A1         Sedans  14500    VAT deductible  73000.0
# 4             Audi A1         Sedans  16790    VAT deductible  16200.0
# ...               ...            ...    ...               ...      ...
# 15799  Renault Espace            Van  47600    VAT deductible  10227.0
# 15811  Renault Espace            Van  54925    VAT deductible  14178.0
# 15826  Renault Espace            Van  49900    VAT deductible  10720.0
# 15838  Renault Espace            Van  46680    VAT deductible  19900.0
# 15891  Renault Espace  Station wagon  42490    VAT deductible  16500.0
#
#                 Type     Fuel  Gears  \
# 0               Used   Diesel    7.0
# ...

# %%
car_data[(car_data['km'] < 10000)]
# Out:
#            make_model body_type  price             vat           km  \
# 16            Audi A1    Sedans  18900  VAT deductible  9752.000000
# 23            Audi A1    Sedans  18850  VAT deductible  9077.000000
# 24            Audi A1    Sedans  18500  VAT deductible  3000.000000
# 68            Audi A1    Sedans  18900  VAT deductible  4250.000000
# 69            Audi A1    Sedans  18890  VAT deductible  2949.000000
# ...               ...       ...    ...             ...          ...
# 15910  Renault Espace       Van  39950  VAT deductible  1647.362609
# 15911  Renault Espace       Van  39885  VAT deductible  9900.000000
# 15912  Renault Espace       Van  39875  VAT deductible    15.000000
# 15913  Renault Espace       Van  39700  VAT deductible    10.000000
# 15914  Renault Espace       Van  40999  VAT deductible  1647.362609
#
#                  Type     Fuel  Gears  \
# 16               Used   Diesel    5.0
# 23               Used   Diesel    7.0
# ...
